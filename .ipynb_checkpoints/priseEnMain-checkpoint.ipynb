# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import numpy as np
import random
data = loadmat('ecg_dataset.mat')
print(data.keys())
print('------------------')
data
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])
# ------------------
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Tue Aug 26 17:46:48 2025',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[-0.61 , -0.61 , -0.595, ..., -0.83 , -0.81 , -0.81 ],
#         [-0.355, -0.375, -0.365, ...,  0.   ,  0.   ,  0.   ],
#         [-0.26 , -0.26 , -0.25 , ...,  0.   ,  0.   ,  0.   ],
#         ...,
#         [-0.23 , -0.235, -0.2  , ...,  0.   ,  0.   ,  0.   ],
#         [ 0.15 ,  0.185,  0.195, ...,  0.   ,  0.   ,  0.   ],
#         [-0.24 , -0.24 , -0.23 , ...,  0.   ,  0.   ,  0.   ]]),
#  'y': array([[0],
#         [0],
#         [1],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8)}

# %%
X = data['X']
Y = data['y'].flatten()
classe, count = np.unique(Y,return_counts=True)
for c, n in zip(classe, count):
    print(f"Classe {c} : {n} échantillons")
# Out:
# Classe 0 : 5288 échantillons
# Classe 1 : 111 échantillons
# Classe 2 : 6 échantillons

# %%
plt.figure(figsize=(12,4))
for c in [0, 1, 2]:
    idx = np.where(Y == c)[0][0] 
    print(f'index = {idx}')
    plt.plot(X[idx], label=f'Classe {c}')
plt.legend()
plt.title("Exemples de signaux par classe")
plt.show()
# Out:
# index = 0
# index = 2
# index = 1148

# %% [markdown]
# # Normalisation des données

# %%
X_norm =(X- X.mean(axis=1, keepdims=True))/(X.std(axis=1, keepdims=True)+1e-8)
X_norm
# Out:
# array([[ 0.93153123,  0.93153123,  1.00821055, ..., -0.19309884,
#         -0.09085975, -0.09085975],
#        [ 0.23055808,  0.13724836,  0.18390322, ...,  1.88680549,
#          1.88680549,  1.88680549],
#        [-0.08324134, -0.08324134, -0.04218311, ...,  0.98427256,
#          0.98427256,  0.98427256],
#        ...,
#        [ 0.11195021,  0.08362312,  0.28191276, ...,  1.41499637,
#          1.41499637,  1.41499637],
#        [ 0.25212855,  0.39560037,  0.43659231, ..., -0.36275065,
#         -0.36275065, -0.36275065],
#        [ 0.24736046,  0.24736046,  0.30039222, ...,  1.52012264,
#          1.52012264,  1.52012264]])

# %% [markdown]
# # Recuperatioin de la classe d'entrainement classe N(0)

# %%
X_normal = X_norm[Y==0][:, :144]
X_anomaly_R = X_norm[Y==1][:, :144]
X_anomaly_V = X_norm[Y==2][:, :144]

# %%
X_training, X_validation = train_test_split(X_normal, test_size=0.2, random_state=42)
X_training = X_training[..., np.newaxis]
X_validation = X_validation[..., np.newaxis]
X_anomaly_R = X_anomaly_R[..., np.newaxis]
X_anomaly_V = X_anomaly_V[..., np.newaxis]
X_normal = X_normal[...,np.newaxis]

# %% [markdown]
# # construction de l'autoencodeur

# %%
data_input =(144, 1)
encoder = models.Sequential([
    layers.Input(shape=data_input),
    layers.Conv1D(8, kernel_size=7, activation='relu', padding='same'),
    layers.MaxPooling1D(pool_size=2),
    layers.Conv1D(16, kernel_size=5, activation='relu', padding='same'),
    layers.MaxPooling1D(pool_size=2),
    layers.Conv1D(32, kernel_size=3, activation='relu', padding='same'),
    layers.Flatten(),
    layers.Dense(16, activation='relu')  
])

decoder = models.Sequential([
    layers.Dense((144 // 4) * 32, activation='relu'),
    layers.Reshape((144 // 4, 32)),
    layers.UpSampling1D(size=2),
    layers.Conv1DTranspose(16, kernel_size=5, activation='relu', padding='same'),
    layers.UpSampling1D(size=2),
    layers.Conv1DTranspose(8, kernel_size=7, activation='relu', padding='same'),
    layers.Conv1D(1, kernel_size=1, activation='linear', padding='same')
])

input_autoencodeur = layers.Input(shape = data_input)
data_encoded= encoder(input_autoencodeur)
data_decoded = decoder(data_encoded)

autoencodeur = models.Model(input_autoencodeur, data_decoded)

# %% [markdown]
# # compilation de l'autoencodeur

# %%
autoencodeur.compile(optimizer='adam', loss = 'mse')

# %% [markdown]
# #entrainement du models

# %%
training_history = autoencodeur.fit(
    X_training, X_training, epochs=50, batch_size=32,
    validation_data=(X_validation, X_validation),
    shuffle=True)
# Out:
# Epoch 1/50
# 133/133 [==============================] - 4s 16ms/step - loss: 0.2000 - val_loss: 0.0556
# Epoch 2/50
# 133/133 [==============================] - 2s 13ms/step - loss: 0.0349 - val_loss: 0.0258
# Epoch 3/50
# 133/133 [==============================] - 2s 13ms/step - loss: 0.0235 - val_loss: 0.0207
# Epoch 4/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0188 - val_loss: 0.0173
# Epoch 5/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0156 - val_loss: 0.0154
# Epoch 6/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0134 - val_loss: 0.0131
# Epoch 7/50
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0120 - val_loss: 0.0122
# Epoch 8/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 9/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 10/50
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 11/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0090 - val_loss: 0.0096
# Epoch 12/50
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 13/50
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0084 - val_loss: 0.0095
# Epoch 14/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 15/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0080 - val_loss: 0.0111
# Epoch 16/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 17/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0076 - val_loss: 0.0086
# Epoch 18/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0075 - val_loss: 0.0081
# Epoch 19/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0073 - val_loss: 0.0079
# Epoch 20/50
# 133/133 [==============================] - 2s 11ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 21/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0071 - val_loss: 0.0077
# Epoch 22/50
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0070 - val_loss: 0.0077
# Epoch 23/50
# 133/133 [==============================] - 2s 11ms/step - loss: 0.0069 - val_loss: 0.0082
# Epoch 24/50
# 133/133 [==============================] - 2s 11ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 25/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 26/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0067 - val_loss: 0.0076
# Epoch 27/50
# 133/133 [==============================] - 2s 13ms/step - loss: 0.0067 - val_loss: 0.0073
# Epoch 28/50
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 29/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0066 - val_loss: 0.0087
# Epoch 30/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0066 - val_loss: 0.0073
# Epoch 31/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0065 - val_loss: 0.0072
# Epoch 32/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0065 - val_loss: 0.0074
# Epoch 33/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0065 - val_loss: 0.0071
# Epoch 34/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 35/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 0.0073
# Epoch 36/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 37/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 38/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 39/50
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 41/50
# 133/133 [==============================] - 1s 10ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 42/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 43/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 44/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0068
# Epoch 45/50
# 133/133 [==============================] - 2s 13ms/step - loss: 0.0060 - val_loss: 0.0070
# Epoch 46/50
# 133/133 [==============================] - 2s 13ms/step - loss: 0.0062 - val_loss: 0.0068
# Epoch 47/50
# 133/133 [==============================] - 2s 13ms/step - loss: 0.0060 - val_loss: 0.0072
# Epoch 48/50
# 133/133 [==============================] - 2s 11ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 49/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 50/50
# 133/133 [==============================] - 2s 12ms/step - loss: 0.0060 - val_loss: 0.0069

# %% [markdown]
# # calcul du scroe d'anomalie(mse)

# %%
def anomaly_score(model, data):
    reconstructon = model.predict(data)
    errors = np.mean((data - reconstructon)**2, axis=(1,2))
    return errors

error_N = anomaly_score(autoencodeur, X_training)
error_R = anomaly_score(autoencodeur, X_anomaly_R)
error_V = anomaly_score(autoencodeur, X_anomaly_V)

print("============ Scroe d'anomalie =============")
print(f'Normales: {error_N}')
print(f'Anomalie R: {error_R}')
print(f'Anomalie V: {error_V}')
# Out:
# 133/133 [==============================] - 1s 4ms/step
# 4/4 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# ============ Scroe d'anomalie =============
# Normales: [0.00481094 0.0029101  0.00500546 ... 0.00370033 0.00216431 0.00520088]
# Anomalie R: [0.09636497 0.08435131 0.09508372 0.07196252 0.06884958 0.08154694
#  0.07454077 0.24283863 0.0951218  0.08389927 0.0846969  0.09430579
#  0.11437822 0.08661562 0.07688347 0.10140819 0.21511772 0.31270021
#  0.12099903 0.08122094 0.15455787 0.08676716 0.07222377 0.0873139
#  0.06350376 0.08126165 0.14368983 0.0558968  0.10622181 0.13930511
#  0.07424297 0.10148099 0.13186131 0.23699455 0.11102002 0.71763118
#  0.07549548 0.12358712 0.07980015 0.25192595 0.11444758 0.24701565
#  0.14186906 0.09635536 0.10598974 0.29496903 0.08020112 0.28146102
#  0.05114089 0.08160197 0.07380942 0.13585885 0.11578173 0.14928144
#  0.29020625 0.06930192 0.07611622 0.05160594 0.12375402 0.07930509
#  0.12532245 0.11442329 0.22345316 0.11503751 0.09903497 0.06475402
#  0.11596088 0.05915383 0.05564879 0.05480679 0.07440476 0.1203244
#  0.09020633 0.13045354 0.12782317 0.0576021  0.10764924 0.09665772
#  0.0927376  0.04263265 0.094653   0.07238185 0.09024534 0.11400076
#  0.12945936 0.08952224 0.10768979 0.13418198 0.26382929 0.25029872
#  0.06506106 0.10119306 0.06260261 0.5957815  0.09022818 0.09382569
#  0.11739188 0.08284899 0.12351141 0.07087393 0.07813462 0.10436094
#  0.10801451 0.19143333 0.10536569 0.08185412 0.11336318 0.08221598
#  0.08475365 0.10620272 0.13085458]
# Anomalie V: [0.48843334 0.10579086 0.08739527 0.33864584 0.27693343 0.37208056]

# %% [markdown]
# # Dertermination du seuil

# %%
seuil = np.percentile(error_N, 99)
print('========== Seuil de detection =============')
print(f'90eme percentil sur les données normales: {seuil:.6f}')
# Out:
# ========== Seuil de detection =============
# 90eme percentil sur les données normales: 0.038099

# %% [markdown]
# Visualition des score d'erreur

# %%
def detect_anomaly(model,x,seuil):
    reconst = model.predict(x)
    error = np.mean((x-reconst)**2)
    return f"Normale, Erreur = {error:.4}" if error < seuil else f"Anomalie detectée, Erreur = {error:.4f}"

# %%
print("Erreurs max :")
print("  Normaux :", np.max(error_N))
print("  Anomalies R :", np.max(error_R))
print("  Anomalies V :", np.max(error_V))
# Out:
# Erreurs max :
#   Normaux : 0.3815439011340951
#   Anomalies R : 0.7176311806189115
#   Anomalies V : 0.48843334408336475

# %%
det_N = np.sum(error_N > seuil)
det_R = np.sum(error_R > seuil)
det_V = np.sum(error_V > seuil)
print("Seuil (99e) =", seuil)
print(f"FP (normaux>seuil): {det_N}/{len(error_N)}")
print(f"R détectées: {det_R}/{len(error_R)}")
print(f"V détectées: {det_V}/{len(error_V)}")
# Out:
# Seuil (99e) = 0.03809862120132446
# FP (normaux>seuil): 43/4230
# R détectées: 111/111
# V détectées: 6/6

# %%
plt.figure(figsize=(8,5))
plt.hist(error_N, bins=50, alpha=0.6, label='Normaux')
plt.hist(error_R, bins=50, alpha=0.6, label='Anomalies R')
plt.hist(error_V, bins=50, alpha=0.6, label='Anomalies V')
plt.axvline(seuil, color='red', linestyle='--', label=f'Seuil (99e)={seuil:.4f}')
plt.xlabel("Erreur de reconstruction (MSE)")
plt.ylabel("Fréquence")
plt.title("Distribution des erreurs de reconstruction")
plt.legend()
plt.show()

# %%
def visualization(signals):
    i = random.randint(0,len(signals)-1)
    original = signals[i].squeeze()
    signal = np.array(signals[i]).reshape(1, 144, 1)
    reconst = autoencodeur.predict(signal, verbose=0)[0].squeeze()
    plt.figure(figsize=(10,4))
    plt.plot(original, label="Original")
    plt.plot(reconst, label="Reconstruit", linestyle="-")
    plt.title(f"*** {detect_anomaly(autoencodeur,signal,seuil)}")
    plt.legend()
    plt.show()

visualization(X_normal)
visualization(X_anomaly_R)
visualization(X_anomaly_V)
# Out:
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step

# %% [markdown]
# #Evaluation des performance du models

# %%
all_errors= np.concatenate([error_N, error_R, error_V])
all_labels = np.concatenate([
    np.zeros_like(error_N),   # normales = 0
    np.ones_like(error_R),    # anomalies R = 1
    np.ones_like(error_V)     # anomalies V = 1
])

# Prédictions binaires
preds_all = (all_errors > seuil).astype(int)

# %%
# Rapport de classification
print(classification_report(all_labels, preds_all, target_names=["Normal", "Anomalie"]))

# Matrice de confusion
cm = confusion_matrix(labels_all, preds_all)
print("Matrice de confusion :\n", cm)

# Aire sous la courbe ROC
auc = roc_auc_score(labels_all, errors_all)
print(f"AUC ROC : {auc:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      0.99      4230
#     Anomalie       0.73      1.00      0.84       117
#
#     accuracy                           0.99      4347
#    macro avg       0.87      0.99      0.92      4347
# weighted avg       0.99      0.99      0.99      4347
#
# Matrice de confusion :
#  [[4187   43]
#  [   0  117]]
# AUC ROC : 0.9983
