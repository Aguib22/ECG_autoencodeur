# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import numpy as np
data = loadmat('ecg_dataset.mat')
print(data.keys())
print('------------------')
data
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])
# ------------------
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Tue Aug 26 17:46:48 2025',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[-0.61 , -0.61 , -0.595, ..., -0.83 , -0.81 , -0.81 ],
#         [-0.355, -0.375, -0.365, ...,  0.   ,  0.   ,  0.   ],
#         [-0.26 , -0.26 , -0.25 , ...,  0.   ,  0.   ,  0.   ],
#         ...,
#         [-0.23 , -0.235, -0.2  , ...,  0.   ,  0.   ,  0.   ],
#         [ 0.15 ,  0.185,  0.195, ...,  0.   ,  0.   ,  0.   ],
#         [-0.24 , -0.24 , -0.23 , ...,  0.   ,  0.   ,  0.   ]]),
#  'y': array([[0],
#         [0],
#         [1],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8)}

# %%
X = data['X']
Y = data['y'].flatten()
classe, count = np.unique(Y,return_counts=True)
for c, n in zip(classe, count):
    print(f"Classe {c} : {n} échantillons")
# Out:
# Classe 0 : 5288 échantillons
# Classe 1 : 111 échantillons
# Classe 2 : 6 échantillons

# %%
plt.figure(figsize=(12,4))
for c in [0, 1, 2]:
    idx = np.where(Y == c)[0][0] 
    print(f'index = {idx}')
    plt.plot(X[idx], label=f'Classe {c}')
plt.legend()
plt.title("Exemples de signaux par classe")
plt.show()
# Out:
# index = 0
# index = 2
# index = 1148

# %% [markdown]
# # Normalisation des données

# %%
#X_norm =(X- X.mean(axis=1, keepdims=True))/(X.std(axis=1, keepdims=True)+1e-8)
X_norm= (X - X.min(axis=1, keepdims=True)) / (X.max(axis=1, keepdims=True) - X.min(axis=1, keepdims=True) + 1e-8)

X_norm
# Out:
# array([[0.79638008, 0.79638008, 0.80995474, ..., 0.59728506, 0.61538461,
#         0.61538461],
#        [0.71020408, 0.69387755, 0.70204081, ..., 0.99999999, 0.99999999,
#         0.99999999],
#        [0.75217391, 0.75217391, 0.76086956, ..., 0.97826086, 0.97826086,
#         0.97826086],
#        ...,
#        [0.75879396, 0.75376884, 0.78894472, ..., 0.98994974, 0.98994974,
#         0.98994974],
#        [0.73636363, 0.76818181, 0.77727272, ..., 0.59999999, 0.59999999,
#         0.59999999],
#        [0.73762376, 0.73762376, 0.74752475, ..., 0.97524752, 0.97524752,
#         0.97524752]])

# %% [markdown]
# # Recuperatioin de la classe d'entrainement classe N(0)

# %%
X_normal = X_norm[Y==0][:, :144]
X_anomaly_V = X_norm[Y==1][:, :144]
X_anomaly_R = X_norm[Y==2][:, :144]

# %%
X_training, X_validation = train_test_split(X_normal, test_size=0.2, random_state=42)
X_training = X_training[..., np.newaxis]
X_validation = X_validation[..., np.newaxis]
X_anomaly_R = X_anomaly_R[..., np.newaxis]
X_anomaly_V = X_anomaly_V[..., np.newaxis]

# %% [markdown]
# # construction de l'autoencodeur

# %%
data_input =(144, 1)
encoder = models.Sequential([
    layers.Input(shape = data_input),
    layers.Conv1D(8, kernel_size=7, activation='relu', padding='same'),
    layers.MaxPooling1D(pool_size=2),
    layers.Conv1D(16, kernel_size=5, activation='relu', padding='same'),
    layers.MaxPooling1D(pool_size=2),
    layers.Conv1D(32, kernel_size=3, activation='relu', padding='same'),
])

decoder = models.Sequential([
    layers.Conv1DTranspose(32, kernel_size=3, activation='relu', padding='same'),
    layers.UpSampling1D(size=2),
    layers.Conv1DTranspose(16, kernel_size=5, activation='relu', padding='same'),
    layers.UpSampling1D(size=2),
    #layers.Conv1DTranspose(16, kernel_size=7, activation='relu', padding='same'),
    layers.Conv1D(1, kernel_size=7, activation='linear', padding='same')
    
])

input_autoencodeur = layers.Input(shape = data_input)
data_encoded= encoder(input_autoencodeur)
data_decoded = decoder(data_encoded)

autoencodeur = models.Model(input_autoencodeur, data_decoded)

# %% [markdown]
# # compilation de l'autoencodeur

# %%
autoencodeur.compile(optimizer='adam', loss = 'mse')

# %% [markdown]
# #entrainement du models

# %%
training_history = autoencodeur.fit(
    X_training, X_training, epochs=40, batch_size=32,
    validation_data=(X_validation, X_validation),
    shuffle=True)
# Out:
# Epoch 1/40
# 133/133 [==============================] - 3s 15ms/step - loss: 0.0300 - val_loss: 0.0011
# Epoch 2/40
# 133/133 [==============================] - 2s 12ms/step - loss: 6.9456e-04 - val_loss: 5.0673e-04
# Epoch 3/40
# 133/133 [==============================] - 2s 12ms/step - loss: 4.3756e-04 - val_loss: 4.0070e-04
# Epoch 4/40
# 133/133 [==============================] - 2s 12ms/step - loss: 3.5828e-04 - val_loss: 3.4329e-04
# Epoch 5/40
# 133/133 [==============================] - 2s 11ms/step - loss: 3.1753e-04 - val_loss: 3.1007e-04
# Epoch 6/40
# 133/133 [==============================] - 2s 12ms/step - loss: 2.8899e-04 - val_loss: 2.9303e-04
# Epoch 7/40
# 133/133 [==============================] - 2s 12ms/step - loss: 2.6930e-04 - val_loss: 2.7305e-04
# Epoch 8/40
# 133/133 [==============================] - 2s 12ms/step - loss: 2.5315e-04 - val_loss: 2.6306e-04
# Epoch 9/40
# 133/133 [==============================] - 2s 12ms/step - loss: 2.3962e-04 - val_loss: 2.6136e-04
# Epoch 10/40
# 133/133 [==============================] - 2s 12ms/step - loss: 2.2750e-04 - val_loss: 2.3104e-04
# Epoch 11/40
# 133/133 [==============================] - 2s 12ms/step - loss: 2.1226e-04 - val_loss: 2.2496e-04
# Epoch 12/40
# 133/133 [==============================] - 2s 12ms/step - loss: 2.0240e-04 - val_loss: 2.0762e-04
# Epoch 13/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.9179e-04 - val_loss: 2.0899e-04
# Epoch 14/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.8423e-04 - val_loss: 1.9187e-04
# Epoch 15/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.7716e-04 - val_loss: 1.9660e-04
# Epoch 16/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.7192e-04 - val_loss: 1.7817e-04
# Epoch 17/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.6132e-04 - val_loss: 1.8244e-04
# Epoch 18/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.5741e-04 - val_loss: 1.5936e-04
# Epoch 19/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.4898e-04 - val_loss: 1.5441e-04
# Epoch 20/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.4512e-04 - val_loss: 1.5322e-04
# Epoch 21/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.3981e-04 - val_loss: 1.4468e-04
# Epoch 22/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.3681e-04 - val_loss: 1.4523e-04
# Epoch 23/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.3403e-04 - val_loss: 1.3808e-04
# Epoch 24/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.2872e-04 - val_loss: 1.7830e-04
# Epoch 25/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.3222e-04 - val_loss: 1.4187e-04
# Epoch 26/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.2539e-04 - val_loss: 1.4545e-04
# Epoch 27/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.2445e-04 - val_loss: 1.2839e-04
# Epoch 28/40
# 133/133 [==============================] - 2s 14ms/step - loss: 1.2086e-04 - val_loss: 1.3111e-04
# Epoch 29/40
# 133/133 [==============================] - 2s 12ms/step - loss: 1.2125e-04 - val_loss: 1.2856e-04
# Epoch 30/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1975e-04 - val_loss: 1.2315e-04
# Epoch 31/40
# 133/133 [==============================] - 2s 14ms/step - loss: 1.2043e-04 - val_loss: 1.2293e-04
# Epoch 32/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1488e-04 - val_loss: 1.1964e-04
# Epoch 33/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1551e-04 - val_loss: 1.2467e-04
# Epoch 34/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1731e-04 - val_loss: 1.3097e-04
# Epoch 35/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1047e-04 - val_loss: 1.4175e-04
# Epoch 36/40
# 133/133 [==============================] - 2s 16ms/step - loss: 1.1694e-04 - val_loss: 1.1462e-04
# Epoch 37/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0808e-04 - val_loss: 1.1528e-04
# Epoch 38/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0774e-04 - val_loss: 1.1497e-04
# Epoch 39/40
# 133/133 [==============================] - 2s 14ms/step - loss: 1.1104e-04 - val_loss: 1.1722e-04
# Epoch 40/40
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0908e-04 - val_loss: 1.1563e-04

# %% [markdown]
# # calcul du scroe d'anomalie(mse)

# %%
def anomaly_score(model, data):
    reconstructon = model.predict(data)
    errors = np.mean((data - reconstructon)**2, axis=(1,2))
    return errors

error_N = anomaly_score(autoencodeur, X_training)
error_R = anomaly_score(autoencodeur, X_anomaly_R)
error_V = anomaly_score(autoencodeur, X_anomaly_V)

print("============ Scroe d'anomalie =============")
print(f'Normales: {error_N}')
print(f'Anomalie R: {error_R}')
print(f'Anomalie V: {error_V}')
# Out:
# 133/133 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 6ms/step
# ============ Scroe d'anomalie =============
# Normales: [8.94714508e-05 5.11625242e-05 8.33916227e-05 ... 6.59172200e-05
#  7.50275618e-05 9.12724913e-05]
# Anomalie R: [8.71206177e-05 8.36332228e-05 2.08056518e-04 1.05946484e-04
#  1.00378087e-04 1.21036830e-04]
# Anomalie V: [3.46868650e-04 1.10254467e-04 4.05281166e-04 2.71932747e-04
#  1.40060959e-04 1.53769454e-04 4.48707050e-04 1.43175974e-04
#  5.22486853e-04 3.75276617e-04 5.24545965e-04 3.40681581e-04
#  2.58277645e-04 2.77979602e-04 2.63643422e-04 2.97838292e-04
#  1.09198765e-04 2.15387189e-04 2.43160519e-04 6.07106228e-04
#  1.15992464e-04 5.54360048e-04 6.48144904e-04 2.80868492e-04
#  3.43542559e-04 5.00602849e-04 3.32730566e-04 2.98881246e-04
#  1.86361831e-04 3.17861583e-04 3.78605088e-04 1.68632493e-04
#  2.79905528e-04 1.63834274e-04 2.63387965e-04 6.86602914e-04
#  3.42309832e-04 1.59876236e-04 5.17760365e-04 2.34250345e-04
#  1.36721875e-03 6.19738916e-04 2.12038052e-04 4.13316564e-04
#  4.31011521e-04 1.25419921e-04 1.57252191e-04 1.51624005e-04
#  2.60256029e-04 3.81349456e-04 4.09416189e-04 1.44145605e-04
#  5.97145900e-04 9.38416513e-05 8.29855542e-05 1.05737303e-04
#  1.57272160e-04 6.46977126e-04 2.00384055e-04 3.69325200e-04
#  2.63008845e-04 3.77632556e-04 1.03332741e-04 2.92343300e-04
#  2.51781844e-04 2.39529178e-04 4.77366178e-04 1.91290056e-04
#  2.93873247e-04 2.94259432e-04 1.49928992e-04 4.43037719e-04
#  4.04092721e-04 1.95847477e-04 2.21565656e-04 1.84781133e-04
#  2.46574744e-04 7.10375282e-04 3.97982298e-04 4.23467547e-04
#  1.81956159e-04 5.83344865e-04 3.72547358e-04 4.56776650e-04
#  3.62708798e-04 2.72800842e-04 2.81301734e-04 8.30416168e-04
#  1.07137413e-04 3.49431526e-04 2.74328480e-04 4.55601517e-04
#  6.09989770e-04 6.62634837e-04 2.15286365e-04 4.25339032e-04
#  1.39694980e-04 2.41850724e-04 5.82485391e-04 3.83398246e-04
#  6.06372658e-04 2.48475184e-04 3.44340960e-04 1.26011197e-04
#  1.39596709e-04 3.91127921e-04 1.75798443e-04 2.19743894e-04
#  3.63573884e-04 1.60762790e-04 1.64453007e-04]

# %% [markdown]
# # Dertermination du seuil

# %%
seuil = np.percentile(error_N, 95)
print('========== Seuil de detection =============')
print(f'90eme percentil sur les données normales: {seuil:.6f}')
print(f'score_errorMAX: {np.max(error_N):.6f}')
# Out:
# ========== Seuil de detection =============
# 90eme percentil sur les données normales: 0.002416
# score_errorMAX: 0.178483

# %% [markdown]
# Visualition des score d'erreur

# %%
plt.figure(figsize=(8,5))
plt.hist(error_N, bins=50, alpha=0.6, label='Normaux',color='green')
plt.hist(error_R, bins=50, alpha=0.6, label='Anomalies R',color='orange')
plt.hist(error_V, bins=50, alpha=0.6, label='Anomalies V',color ='red')
plt.axvline(seuil, color='black', linestyle='--', label=f'Seuil (95e) = {seuil:.4f}')
plt.xlabel('Erreur de reconstruction (MSE)')
plt.ylabel('Fréquence')
plt.title('Distribution des erreurs de reconstruction')
plt.legend()
plt.show()
